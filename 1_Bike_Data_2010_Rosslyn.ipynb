# %%
import pandas as pd
# Out:
# /Users/johnkabler/anaconda/lib/python2.7/site-packages/pytz/__init__.py:35: UserWarning: Module argparse was already imported from /Users/johnkabler/anaconda/python.app/Contents/lib/python2.7/argparse.pyc, but /Users/johnkabler/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
pd.set_option('display.mpl_style', 'default')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
kb_2010 = pd.read_csv('2010_Custis_Rosslyn01.01_12.31_15mins.csv', parse_dates=['Date'], index_col='Date')

# %%
kb_2010
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35040 entries, 2010-01-01 00:00:00 to 2010-12-31 00:00:00
# Data columns (total 4 columns):
# Unnamed: 1             35040  non-null values
# Custis Rosslyn         35036  non-null values
# Custis Rosslyn Ped     35036  non-null values
# Custis Rosslyn Bike    35036  non-null values
# dtypes: float64(3), object(1)

# %%
kb_2010 = kb_2010.drop('Unnamed: 1', axis=1)

# %%
kb_2010 = kb_2010.sort_index()

# %%
kb_2010['Custis Rosslyn Bike'][:5]
# Out:
# Date
# 2010-01-01    0
# 2010-01-01    0
# 2010-01-01    0
# 2010-01-01    0
# 2010-01-01    0
# Name: Custis Rosslyn Bike, dtype: float64

# %%
kb_2010['Custis Rosslyn Bike'].plot(figsize=(20,10))

# %%
kb_2010.index.day
# Out:
# array([ 1,  1,  1, ..., 31, 31, 31], dtype=int32)

# %%
kb_2010.index.weekday
# Out:
# array([4, 4, 4, ..., 4, 4, 4], dtype=int32)

# %%
kb_2010['day_of_week'] = kb_2010.index.weekday

# %%
kb_2010_weekday = kb_2010.groupby('day_of_week').aggregate(np.sum)

# %%
kb_2010_weekday
# Out:
#              Custis Rosslyn  Custis Rosslyn Ped  Custis Rosslyn Bike  month  \
# day_of_week
# 0                     68154               17219                50935  32544
# 1                     73050               17959                55091  32640
# 2                     72301               18702                53599  32832
# 3                     73636               19836                53800  33024
# 4                     68482               17768                50714  33216
# 5                     69277               22229                47048  32160
# 6                     60123               19542                40581  32256
#
#                day
# day_of_week
# 0            77088
# 1            79104
# 2            78240
# 3            77376
# 4            79584
# 5            78720
# 6            80736

# %%
kb_2010_weekday.index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
kb_2010_weekday
# Out:
#            Custis Rosslyn  Custis Rosslyn Ped  Custis Rosslyn Bike  month    day
# Monday              68154               17219                50935  32544  77088
# Tuesday             73050               17959                55091  32640  79104
# Wednesday           72301               18702                53599  32832  78240
# Thursday            73636               19836                53800  33024  77376
# Friday              68482               17768                50714  33216  79584
# Saturday            69277               22229                47048  32160  78720
# Sunday              60123               19542                40581  32256  80736

# %%
kb_2010_weekday.plot()

# %%
kb_2010.index.month
# Out:
# array([ 1,  1,  1, ..., 12, 12, 12], dtype=int32)

# %%
kb_2010['month'] = kb_2010.index.month

# %%
kb_2010['day'] = kb_2010.index.day

# %%
kb_2010_sums = kb_2010.groupby(['month', 'day']).aggregate(np.sum)

# %%
kb_2010_sums
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 365 entries, (1, 1) to (12, 31)
# Data columns (total 4 columns):
# Custis Rosslyn         365  non-null values
# Custis Rosslyn Ped     365  non-null values
# Custis Rosslyn Bike    365  non-null values
# day_of_week            365  non-null values
# dtypes: float64(3), int32(1)

# %%
kb_2010_sums.plot(figsize=(20,10))
