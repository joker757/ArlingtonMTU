# %%
import pandas as pd
pd.set_option('display.mpl_style', 'default')
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
weather_2010 = pd.read_csv('Weather2010.csv', parse_dates='EST', index_col='EST')

# %%
weather_2010['Mean TemperatureF'].plot(figsize=(15,5))

# %%
weather_2010
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2010-01-01 00:00:00 to 2010-12-31 00:00:00
# Data columns (total 22 columns):
# Max TemperatureF              365  non-null values
# Mean TemperatureF             365  non-null values
# Min TemperatureF              365  non-null values
# Max Dew PointF                365  non-null values
# MeanDew PointF                365  non-null values
# Min DewpointF                 365  non-null values
# Max Humidity                  365  non-null values
#  Mean Humidity                365  non-null values
#  Min Humidity                 365  non-null values
#  Max Sea Level PressureIn     365  non-null values
#  Mean Sea Level PressureIn    365  non-null values
#  Min Sea Level PressureIn     365  non-null values
#  Max VisibilityMiles          365  non-null values
#  Mean VisibilityMiles         365  non-null values
#  Min VisibilityMiles          365  non-null values
#  Max Wind SpeedMPH            365  non-null values
# ...

# %%
weather_2010[['Mean TemperatureF',' Events']][:60]
# Out:
#             Mean TemperatureF         Events
# EST
# 2010-01-01                 37            NaN
# 2010-01-02                 25            NaN
# 2010-01-03                 22            NaN
# 2010-01-04                 29            NaN
# 2010-01-05                 32           Snow
# 2010-01-06                 34           Snow
# 2010-01-07                 34           Snow
# 2010-01-08                 28       Fog-Snow
# 2010-01-09                 30            NaN
# 2010-01-10                 26            NaN
# 2010-01-11                 28            NaN
# 2010-01-12                 32            NaN
# 2010-01-13                 36            NaN
# 2010-01-14                 38            NaN
# 2010-01-15                 43            NaN
# 2010-01-16                 42            NaN
# 2010-01-17                 41           Rain
# 2010-01-18                 47            NaN
# 2010-01-19                 47           Rain
# 2010-01-20                 40      Rain-Snow
# ...

# %%
rainy_days = weather_2010[' Events'] == 'Rain'

# %%
snowy_days = weather_2010[' Events'] == 'Snow'

# %%
bad_weather_days = rainy_days | snowy_days

# %%
bad_weather_days.plot()

# %% [markdown]
# ## Bike Data Combined with Weather Data

# %%
kb_2010 = pd.read_csv('2010_Custis_Rosslyn01.01_12.31_15mins.csv', parse_dates=['Date'], index_col='Date')

# %%
kb_2010
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 35040 entries, 2010-01-01 00:00:00 to 2010-12-31 00:00:00
# Data columns (total 4 columns):
# Unnamed: 1             35040  non-null values
# Custis Rosslyn         35036  non-null values
# Custis Rosslyn Ped     35036  non-null values
# Custis Rosslyn Bike    35036  non-null values
# dtypes: float64(3), object(1)

# %%
bike_2010 = kb_2010['Custis Rosslyn Bike'].resample('D',how=np.sum)

# %%
type(bike_2010)
# Out:
# pandas.core.series.TimeSeries

# %%
bikes = pd.DataFrame(bike_2010)

# %%
bikes.columns
# Out:
# Date
# 2010-01-01     112
# 2010-01-02      34
# 2010-01-03     397
# 2010-01-04    1701
# 2010-01-05    1342
# 2010-01-06    1293
# 2010-01-07    1886
# 2010-01-08    1107
# 2010-01-09    1569
# 2010-01-10    1149
# 2010-01-11    1085
# 2010-01-12     303
# 2010-01-13     455
# 2010-01-14     610
# 2010-01-15     620
# ...
# 2010-12-17     57
# 2010-12-18     19
# 2010-12-19     36
# 2010-12-20    157
# 2010-12-21    183
# 2010-12-22    291
# 2010-12-23    226
# 2010-12-24     72
# 2010-12-25     26
# 2010-12-26     40
# 2010-12-27     47
# 2010-12-28    196
# 2010-12-29    363
# 2010-12-30    349
# 2010-12-31    349
# Freq: D, Name: 0, Length: 365, dtype: float64

# %%
type(weather_2010)
# Out:
# pandas.core.frame.DataFrame

# %%
weather_bike_2010 = pd.merge(weather_2010, bikes, left_index=True, right_index=True)

# %%
weather_bike_2010[[:50]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 50 entries, 2010-01-01 00:00:00 to 2010-02-19 00:00:00
# Data columns (total 23 columns):
# Max TemperatureF              50  non-null values
# Mean TemperatureF             50  non-null values
# Min TemperatureF              50  non-null values
# Max Dew PointF                50  non-null values
# MeanDew PointF                50  non-null values
# Min DewpointF                 50  non-null values
# Max Humidity                  50  non-null values
#  Mean Humidity                50  non-null values
#  Min Humidity                 50  non-null values
#  Max Sea Level PressureIn     50  non-null values
#  Mean Sea Level PressureIn    50  non-null values
#  Min Sea Level PressureIn     50  non-null values
#  Max VisibilityMiles          50  non-null values
#  Mean VisibilityMiles         50  non-null values
#  Min VisibilityMiles          50  non-null values
#  Max Wind SpeedMPH            50  non-null values
# ...
